# %% [markdown]
# <a href="https://colab.research.google.com/github/FFANCULO/fart/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pdb
import dropbox

auth_flow = dropbox.DropboxOAuth2FlowNoRedirect("gjz5gih7mubzpex", "4175xs53u8jt5pc")
authorize_url = auth_flow.start()
print(f"1. Go to: {authorize_url}")
print("2. Click \"Allow\" (you might have to log in first).")
print("3. Copy the authorization code.")
auth_code = input("Enter the authorization code here: ").strip()
access_token, user_id = auth_flow.finish(auth_code)
dbx = dropbox.Dropbox(access_token)

pdb.set_trace()


# Create a Dropbox client
dbx = dropbox.Dropbox(access_token)

# List the contents of the root directory
result = dbx.files_list_folder(path='')

pdb.set_trace()
# Print the name of each file or folder
for entry in result.entries:
    print(entry.name)




# Set the API endpoint URL and access token https://api.dropboxapi.com/2/file_requests/list_v2
# url = "https://content.dropboxapi.com/2/files/download"
url = "https://api.dropboxapi.com/2/file_requests/list_v2"
access_token = "sl.BZSGgMPGSHXT_8BcS2RFmCHPtkMTpJYWKopJGj7LK9v1sDFafUv-kBJiSE3uWfLjywUJb4B4r9bgfe2kQhK12x6icJoMRLqvFPrX6HEU7bf51nbSZ_I3SWSqhSGboBkfEXrKkImCboUt"

# Set the request headers
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
 }

# Send the API request
response = requests.post(url, headers=headers)

# Get the contents of the file
file_content = response.content



# Do something with the file contents, e.g. write to a file
with open("filename.ext", "wb") as f:
    f.write(file_content)
# Out:
# 1. Go to: https://www.dropbox.com/oauth2/authorize?response_type=code&client_id=gjz5gih7mubzpex
# 2. Click "Allow" (you might have to log in first).
# 3. Copy the authorization code.
# Enter the authorization code here: TkFgla4t0zoAAAAAAAGcoHJFxK0xJVPhB36FscYOkns
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b233737fd078> in <module>
#       9 print("3. Copy the authorization code.")
#      10 auth_code = input("Enter the authorization code here: ").strip()
# ---> 11 access_token, user_id = auth_flow.finish(auth_code)
#      12 dbx = dropbox.Dropbox(access_token)
#      13
#
# TypeError: cannot unpack non-iterable OAuth2FlowNoRedirectResult object

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import tensorflow as tf

drive.mount('/content/gdrive')

# Note that the path to the file on Google Drive starts with /content/gdrive/MyDrive/ and then the file path relative to the root folder of your Google Drive. You can replace data.csv with the name of the file you want to read, and use other file reading functions like open
# or libraries like numpy to read other types of files.

file_path = "/content/gdrive/MyDrive/Data/VoyageCalc_8.csv"
data = pd.read_csv(file_path)

# You can now work with the data
#print(data.head())

# Load the data from a CSV file using Pandas
df = pd.read_csv(file_path)

# Define the index of the column to drop and all columns after it
cols_to_drop = df.columns[4:8].values
print('cols_to_drop')
print(cols_to_drop)

# Drop the columns using iloc indexing
df = df.drop(cols_to_drop, axis=1)


# Print the updated DataFrame
print(df.head())



data = df.values

# Normalize the data
data = (data - np.mean(data, axis=0)) / np.std(data, axis=0)

# Define the autoencoder
input_shape = (9,)
encoding_dim = 4

# Encoder
input_data = tf.keras.layers.Input(shape=input_shape)
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu')(input_data)

# Decoder
decoded = tf.keras.layers.Dense(input_shape[0], activation='linear')(encoded)

# Autoencoder model
autoencoder = tf.keras.models.Model(inputs=input_data, outputs=decoded)

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='mse')

# Train the autoencoder on the data
autoencoder.fit(data, data, epochs=50)

# Extract the encoded data
encoder = tf.keras.models.Model(inputs=input_data, outputs=encoded)
encoded_data = encoder.predict(data)

# Convert the encoded data to a DataFrame
encoded_df = pd.DataFrame(data=encoded_data, columns=['encoded_1', 'encoded_2', 'encoded_3', 'encoded_4'])

# Save the encoded data to a CSV file
encoded_df.to_csv('/content/gdrive/MyDrive/Encoded/encoded_data.csv', index=False) # replace 'encoded_data.csv' with the path to your output file
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# cols_to_drop
# [' Accel Z' ' Latitude' ' Longitude' ' bearing']
#    Displacement X   Displacement Y   Accel X   Accel Y   velocity     radius  \
# 0       -0.098713        -0.278448  0.428900  0.025754   0.295428   0.220596
# 1        0.862956        -0.263513  0.374828  0.204187   0.902293   2.671444
# 2        1.421960        -0.352023  0.236518  0.286796   1.464886   6.401273
# 3        1.646799        -0.036081  0.261613  0.297550   1.647194   8.948439
# 4        1.777525        -0.012888  0.229034  0.111319   1.777572  27.968217
#
#     bearing variance      cent    tangen
# 0           1.841203  0.395644  0.034029
# 1          -1.678214  0.304754  0.122082
# 2           1.491380  0.335229  0.036514
# 3           0.032266  0.303209  0.092995
# 4           0.267661  0.112977  0.141677
# Epoch 1/50
# 64/64 [==============================] - 2s 14ms/step - loss: 1.2979
# Epoch 2/50
# 64/64 [==============================] - 0s 2ms/step - loss: 1.1468
# Epoch 3/50
# 64/64 [==============================] - 0s 2ms/step - loss: 1.0504
# Epoch 4/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.9780
# Epoch 5/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.9203
# Epoch 6/50
# 64/64 [==============================] - 0s 6ms/step - loss: 0.8692
# Epoch 7/50
# 64/64 [==============================] - 0s 1ms/step - loss: 0.8253
# Epoch 8/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.7872
# Epoch 9/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.7546
# Epoch 10/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.7279
# Epoch 11/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.7053
# Epoch 12/50
# 64/64 [==============================] - 0s 5ms/step - loss: 0.6863
# Epoch 13/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.6695
# Epoch 14/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.6540
# Epoch 15/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.6403
# Epoch 16/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.6271
# Epoch 17/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.6155
# Epoch 18/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.6033
# Epoch 19/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5917
# Epoch 20/50
# 64/64 [==============================] - 1s 15ms/step - loss: 0.5808
# Epoch 21/50
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5704
# Epoch 22/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5609
# Epoch 23/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5518
# Epoch 24/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5434
# Epoch 25/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5361
# Epoch 26/50
# 64/64 [==============================] - 0s 7ms/step - loss: 0.5289
# Epoch 27/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5229
# Epoch 28/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5171
# Epoch 29/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5118
# Epoch 30/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5071
# Epoch 31/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5026
# Epoch 32/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4980
# Epoch 33/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4941
# Epoch 34/50
# 64/64 [==============================] - 1s 15ms/step - loss: 0.4905
# Epoch 35/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.4873
# Epoch 36/50
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4840
# Epoch 37/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4811
# Epoch 38/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4785
# Epoch 39/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4755
# Epoch 40/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4729
# Epoch 41/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4707
# Epoch 42/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4678
# Epoch 43/50
# 64/64 [==============================] - 1s 15ms/step - loss: 0.4658
# Epoch 44/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.4633
# Epoch 45/50
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4606
# Epoch 46/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4582
# Epoch 47/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4559
# Epoch 48/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4537
# Epoch 49/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4515
# Epoch 50/50
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4490
# 64/64 [==============================] - 2s 26ms/step

# %%
# !pip install pyproj
import pandas as pd
import pyproj

# Define the input GPS coordinates
latitudes = [37.7749, 37.7750, 37.7751, 37.7752]
longitudes = [-122.4194, -122.4193, -122.4192, -122.4191]

# Create a pandas DataFrame from the coordinates
df = pd.DataFrame({'latitude': latitudes, 'longitude': longitudes})

# Define the input and output coordinate reference systems
input_crs = pyproj.CRS('EPSG:4326') # WGS84 (GPS)
output_crs = pyproj.CRS('EPSG:3857') # Web Mercator

# Define the transformation function
transformer = pyproj.Transformer.from_crs(input_crs, output_crs, always_xy=True)

# Transform the GPS data to the output CRS
x, y = transformer.transform(df['longitude'], df['latitude'])

# Create a new DataFrame with the transformed coordinates
transformed_df = pd.DataFrame({'x': x, 'y': y})

# Add 50 feet to the x-coordinates
transformed_df['x'] += 50

print(df)
print(transformed_df)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyproj
#   Downloading pyproj-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from pyproj) (2022.12.7)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.4.1
#    latitude  longitude
# 0   37.7749  -122.4194
# 1   37.7750  -122.4193
# 2   37.7751  -122.4192
# 3   37.7752  -122.4191
#               x             y
# 0 -1.362762e+07  4.547675e+06
# 1 -1.362760e+07  4.547689e+06
# 2 -1.362759e+07  4.547704e+06
# 3 -1.362758e+07  4.547718e+06
